# %%
import json, requests
import urllib.request
import io
import numpy as np
import ast ,cv2
import base64
#url = 'http://72.52.111.176:80/'
url='http://localhost:5000'
image = cv2.imread("images.jpg", 0).tolist()
params = dict(image1=image)
headers={"Token":"kdjsdskacvbbc217vpewe"}
resp = requests.post(url=url, data=json.dumps(params), headers=headers)
print ((resp.text))
# Out:
# {
#   "confidence": "0.9849309921264648",
#   "emotion": "Angry"
# }

# %%
import matplotlib.pyplot as plt
image = cv2.imread("images.jpg")
plt.imshow(image)
plt.show(image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cf78d456b09e> in <module>()
#       2 image = cv2.imread("images.jpg")
#       3 plt.imshow(image)
# ----> 4 plt.show(image)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     250     """
#     251     global _show
# --> 252     return _show(*args, **kw)
#     253
#     254
#
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39         # only call close('all') if any to close
#      40         # close triggers gc.collect, which can be slow
# ---> 41         if close and Gcf.get_all_fig_managers():
#      42             matplotlib.pyplot.close('all')
#      43
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
